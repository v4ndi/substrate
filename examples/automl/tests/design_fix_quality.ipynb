# %% [markdown]
# # AutoML metric-registry quality checkpoint
#
# Repository-only reproducibility notebook. It reuses the fixed 200k-row datasets and compares the metric-registry migration with `after_point_8`; it never regenerates the reference.

# %%
from pathlib import Path

from design_fix_quality import run_checkpoint

artifact_root = Path('../../../../outputs/design_fix_migration').resolve()

# %%
checkpoint_name = 'after_metric_registry'
run_checkpoint(artifact_root, checkpoint_name)

# %%
summary_path = artifact_root / 'checkpoints' / checkpoint_name / 'summary.json'
summary_path
